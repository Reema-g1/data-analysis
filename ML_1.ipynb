# %%
#EMAI640 – Machine Learning
#Assignment 1
#Date:  16/2/2024
#Name: Reema Aldanish
#KAU ID: 2402807
#Section: A01



#import necessary libraries ..
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_breast_cancer
#load Breast Cancer Wisconsin dataset ..
data = load_breast_cancer()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = data.target
#view the top 5 rows of the dataset ..
print(df.head())
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %% [markdown]
# We loaded Breast Cancer dataset from (sklearn.datasets) library with Pandas DataFrame . Also, we add a new column named (target) represent the classification of tumor either malignant or benign. and we show the five first rows of the DataFrame to provide a view of the dataset.

# %%
#view a summary of the data using the describe() function ..
print(df.describe())
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %% [markdown]
# In this code we provide a statistical summary of the columns in the data set such as count, mean, standard deviation, minimum, quartiles, and maximum.

# %%
import matplotlib.pyplot as plt
#creating a histogram using matplotlib ..
#'bins=30' specifies that each histogram should have 30 bins ..
#'figsize=(15, 10)' sets the size of the figure to 15 inches by 10 inches ..
#'color="#F26B8A"' ..
df.hist(bins=30, figsize=(15, 10), color="#F26B8A")
plt.subplots_adjust(hspace=1.5)
plt.show()

# %% [markdown]
# We create histograms for many features form the dataset. Each histogram shows distribution of the values. The histogram for (target) shows the classifications between benign and malignant tumors.

# %%
import matplotlib.pyplot as plt
#creating a boxplot ..
#calculate number of rows needed for 5 boxplots per row ..
n_features = len(df.columns) - 1
n_rows = n_features // 5 + (n_features % 5 > 0)
#plot boxplots for features, exclude 'target' ..
df.drop('target', axis=1).plot(kind='box', subplots=True, layout=(n_rows,5), figsize=(20, n_rows * 3))
plt.tight_layout()
plt.show()

# %% [markdown]
# In this code we display many boxplots that show the distribution of some features with the median value inside the box. Boxplots show the outliers as a point out the boxes. Boxplots are helpful when we need to identify outliers in each feature of the dataset.

# %%
import seaborn as sns
#creating a correlation matrix ..
#set up the matplotlib figure size ..
plt.figure(figsize=(30, 15))
#compute the correlation matrix for dataframe excluding 'target' column ..
sns.heatmap(df.drop('target', axis=1).corr(), annot=True, fmt=".2f",cmap='viridis')
plt.show()

# %% [markdown]
# This code is used to create a heatmap of a correlation matrix, first it removes the column (target) from the dataset. In the heatmap each cell shows the correlation coefficient between two variables -1 to 1. A coefficient close to 1 indicates a strong positive correlation and a coefficient close to -1 indicates a strong negative correlation. The heatmap uses colors to give us a better understanding for variables and the relationship between them, and identify the most important variable for predicting (target) variable.

# %%
#checking for missing values ..
print(df.isnull().sum())

#no missing values in this dataset ..
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# target                     0
# dtype: int64

# %% [markdown]
# The code check for missing values in a dataset, and according to the output shown there are no missing values in the dataset. If there were missing values we can use the function (fillna) or ( inplace) to fill the empty cells with the mean of each column.

# %%
#checking for data types ..
print(df.dtypes)
# All features are numerical, and the target is binary (0 or 1).
# Out:
# mean radius                float64
# mean texture               float64
# mean perimeter             float64
# mean area                  float64
# mean smoothness            float64
# mean compactness           float64
# mean concavity             float64
# mean concave points        float64
# mean symmetry              float64
# mean fractal dimension     float64
# radius error               float64
# texture error              float64
# perimeter error            float64
# area error                 float64
# smoothness error           float64
# compactness error          float64
# concavity error            float64
# concave points error       float64
# symmetry error             float64
# fractal dimension error    float64
# worst radius               float64
# worst texture              float64
# worst perimeter            float64
# worst area                 float64
# worst smoothness           float64
# worst compactness          float64
# worst concavity            float64
# ...

# %% [markdown]
# The code checks the data types of each column in the dataset, the output shows all of the columns with their data type. We can see that all the data in the columns are numerical and discrete variables, and the column (target) has binary value.

# %%
from sklearn.preprocessing import StandardScaler
#feature scaling ..
scaler = StandardScaler()
#scale features by removing the mean and scaling to unit variance ..
X_scaled = scaler.fit_transform(df.drop('target', axis=1))
#assign the target variable ..
y = df['target']

# %% [markdown]
# The code uses the scikit-learn library for process data and ensure that there is no feature with large values. The code use (StandardScaler) to transform data to have mean value of 0 and a standard deviation of 1. There is no output because StandardScaler. results are stored in the specified variables (X_scaled and y)

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
#splitting the dataset ..
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
#train Naive Bayes classifier ..
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# The code divides the dataset into training and testing groups, and trains Naive Bayes classifier by using the Gaussian Naive Bayes algorithm. train_test_split divide the scaled data and (target) to training and testing sets. setting aside 20% of the data for testing with test_size=0.2 and fixing randomness with random_state=42 to ensure reproducible results each time the code is executed.

# %%
#compare the train-set and test-set accuracy ..
train_accuracy = model.score(X_train, y_train)
test_accuracy = model.score(X_test, y_test)
#output accuracy scores ..
print(f"Train Accuracy: {train_accuracy}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Train Accuracy: 0.9362637362637363
# Test Accuracy: 0.9649122807017544

# %% [markdown]
# This code compares accuracy of a classification model on two datasets: the training set and the test set. Using the score function to calculate the model's accuracy. The printed result shows that the accuracy on the training set is about 93.63%, and on the test set, it's about 96.49%. this mean that the model predicts with high accuracy on both sets, and has a good generalization capability. Usually test accuracy is lower than training accuracy, but here test accuracy is higher, which is and positive.

# %%
from sklearn.metrics import classification_report
#predict on test set ..
y_pred = model.predict(X_test)
#generate and print classification report for performance metrics ..
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.93      0.95        43
#            1       0.96      0.99      0.97        71
#
#     accuracy                           0.96       114
#    macro avg       0.97      0.96      0.96       114
# weighted avg       0.97      0.96      0.96       114

# %% [markdown]
# This code evaluates the performance of a classification model on a dataset by comparing the predicted values (y_pred) against the actual values (y_test). The results show that the model has a high accuracy in predicting the classes, values indicate excellent model performance in classifying the categories, the model performs well in predicting the presence of malignant or benign tumors based on the given features. These results reflect the model's ability to learn from the data provided by the breast cancer dataset and apply what it has learned to accurately classify tumors.

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

#plot the confusion matrix ..
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt="d", cmap='viridis')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %% [markdown]
# The code creates confusion matrix and visualizing it with a heatmap for the predicted labels and actual numbers. The confusion matrix shows performance of the model between malignant (represented as 1) and benign (represented as 0) breast cancer tumors.
# the count of 40 represents the true negatives (TN), indicating the number of benign tumors that were correctly identified by the model. The cell with the count of 70 represents the true positives (TP), indicating the number of malignant tumors that were correctly identified. The cell with the count of 3 represents the false positives (FP), where the model incorrectly identified benign tumors as malignant. The cell with the count of 1 represents the false negatives (FN), where the model incorrectly identified a malignant tumor as benign. This model has high performance, as indicated by the high number of TP and TN and the low number of FP and FN. The model has a high effectiveness in predicting breast cancer tumor.
